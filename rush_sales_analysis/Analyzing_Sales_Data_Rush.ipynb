# %% [markdown]
# ## Final Project: Analyzing Sales Data for a Sportswear and Footwear Company
#
# I work as a sales analyst for RUSH, a globally renowned sportswear and footwear brand known for its innovative designs and performance-oriented products. The company stores its raw sales data as a collection of three tables:
#
# *   TABLE_PRODUCTS
# *   TABLE_RETAILER
# *   TABLE_SALES
#
# The VP of US Sales has tasked you with analyzing sales data for trends and insights that will help company leadership understand the market and identify opportunities for growth.
#
# In addition, she has asked you to answer the following business questions:
#
# *   What product category (product) had the highest sales (in dollars) in 2021? How much did it sell?
# *   What state had the highest sales (in dollars) of women's products in 2021? How much was it?
# *   What state had the highest sales (in dollars) of men's products in 2021? How much was it?
# *   What retailer purchased the most units in 2021? In 2020?

# %% [markdown]
# ## Load In Data

# %%
# import python libraries
import pandas as pd
import numpy as np

# %%
# read and preview products file
products = pd.read_csv('/content/TABLE_PRODUCTS_885.csv')
products.head()
# Out:
#          PRODUCT_ID|PRODUCT_NAME
# 0      020|Men's Street Footwear
# 1    030|Men's Athletic Footwear
# 2    120|Women's Street Footwear
# 3  130|Women's Athletic Footwear
# 4              040|Men's Apparel

# %%
# read and preview retailer file
retailer = pd.read_csv('/content/TABLE_RETAILER_885.csv')
retailer.head()
# Out:
#   RETAILER_ID RETAILER     REGION          STATE        CITY
# 0    A00MOHCO   Amazon    Midwest           Ohio    Columbus
# 1    A00NMAPO   Amazon  Northeast          Maine    Portland
# 2    A00NMABO   Amazon  Northeast  Massachusetts      Boston
# 3    A00NNEMA   Amazon  Northeast  New Hampshire  Manchester
# 4    A00NVEBU   Amazon  Northeast        Vermont  Burlington

# %%
# read and preview sales file
sales = pd.read_csv('/content/TABLE_SALES_885.csv')
sales.head()
# Out:
#    ORDER_ID RETAILER_ID INVOICE_DATE  MONTH  DAY  YEAR  PRODUCT_ID  \
# 0         1    A00MOHCO     1/1/2020      1    1  2020          20
# 1         7    A00MOHCO     1/7/2020      1    7  2020          20
# 2        13    A00MOHCO    1/25/2020      1   25  2020          20
# 3        19    A00MOHCO    1/31/2020      1   31  2020          20
# 4        25    A00MOHCO     2/6/2020      2    6  2020          20
#
#    PRICE_PER_UNIT UNITS_SOLD  OPERATING_MARGIN SALES_METHOD
# 0            50.0       1200               0.5     In-store
# 1            50.0       1250               0.5     In-store
# 2            50.0       1220               0.5       Outlet
# 3            50.0       1200               0.5       Outlet
# 4            60.0       1220               0.5       Outlet

# %%
# the delimiter for the products tables is a pipe (|) so I need to use a sep argument
products = pd.read_csv('/content/TABLE_PRODUCTS_885.csv', sep='|')
products.head()
# Out:
#    PRODUCT_ID               PRODUCT_NAME
# 0          20      Men's Street Footwear
# 1          30    Men's Athletic Footwear
# 2         120    Women's Street Footwear
# 3         130  Women's Athletic Footwear
# 4          40              Men's Apparel

# %% [markdown]
# ## Inspection
#
# Looking for:
#
#
# *   Unwanted Observations
# *   Unwanted Features
# *   Incorrect Data Formats or Datatypes
# *   Duplicate Values
# *   Missing Values
# *   Erroneous Values
# *   Outliers

# %% [markdown]
# ### Inspection: products table

# %%
# No unwanted observations or unwanted features to be found in any of tables

# %%
# Incorrect data formats or data types: products
products.info()
# product_id should be an object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT_ID    6 non-null      int64
#  1   PRODUCT_NAME  6 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
# sum of duplicate values: products
products.duplicated().sum()

print(f'Sum of duplicate values - products: {products.duplicated().sum()}')
# Out:
# Sum of duplicate values - products: 0

# %%
# look for traditonal null or missing values: products
products.isnull().sum()
# 0
# Out:
# PRODUCT_ID      0
# PRODUCT_NAME    0
# dtype: int64

# %%
# Non-traditional null values; categorical data: products
# identify unqique values in all categorical fields

# list of categorical variables in dataframe
cat_var = list(products.select_dtypes(include=['object']).columns)

# view unique values for each categorical variable
for column in cat_var:
  print(column)
  print(products[column].unique())

# nothing out of the ordinary here
# Out:
# PRODUCT_NAME
# ["Men's Street Footwear" "Men's Athletic Footwear"
#  "Women's Street Footwear" "Women's Athletic Footwear" "Men's Apparel"
#  "Women's Apparel"]

# %%
# Non-traditional null values; numeric data: products
products.describe()
# Out:
#        PRODUCT_ID
# count    6.000000
# mean    80.000000
# std     55.497748
# min     20.000000
# 25%     32.500000
# 50%     80.000000
# 75%    127.500000
# max    140.000000

# %%
# check for duplicate ids: products
products['PRODUCT_ID'].value_counts()[lambda x: x > 1]
# 0
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ### Inspection: retailer table

# %%
# Incorrect data formats or data types: retailer
retailer.info()
# nothing out of ordinary here
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RETAILER_ID  110 non-null    object
#  1   RETAILER     110 non-null    object
#  2   REGION       110 non-null    object
#  3   STATE        110 non-null    object
#  4   CITY         110 non-null    object
# dtypes: object(5)
# memory usage: 4.4+ KB

# %%
# sum of duplicates: retailer
retailer.duplicated().sum()

print(f'Sum of duplicate values - retailer: {retailer.duplicated().sum()}')
# Out:
# Sum of duplicate values - retailer: 0

# %%
# look for traditonal null or missing values: retailer
retailer.isnull().sum()
# 0
# Out:
# RETAILER_ID    0
# RETAILER       0
# REGION         0
# STATE          0
# CITY           0
# dtype: int64

# %%
# Non-traditional null values; categorical data: retailer

cat_var2 = list(retailer.select_dtypes(include=['object']).columns)

for column in cat_var2:
  print(column)
  print(retailer[column].unique())
# Out:
# RETAILER_ID
# ['A00MOHCO' 'A00NMAPO' 'A00NMABO' 'A00NNEMA' 'A00NVEBU' 'A00SALBI'
#  'A00SKELO' 'A00SNOCH' 'A00WALAN' 'F00MILCH' 'F00MIODE' 'F00MKAWI'
#  'F00MMIDE' 'F00MMIMI' 'F00MMIST' 'F00MNEOM' 'F00MNOFA' 'F00MSOSI'
#  'F00NCOHA' 'F00NDEWI' 'F00NMABA' 'F00NNEMA' 'F00NNENE' 'F00NPEPH'
#  'F00NRHPR' 'F00NWECH' 'F00SLONE' 'F00SMIJA' 'F00STEKN' 'F00STEDA'
#  'F00SFLMI' 'F00SGEAT' 'F00SKELO' 'F00SSOCH' 'F00SVIRI' 'F00WALAN'
#  'F00WARPH' 'F00WCALO' 'F00WHAHO' 'F00WIDBO' 'F00WWASE' 'F00WWYCH'
#  'K00MKAWI' 'K00MMIMI' 'K00MMOBI' 'K00NDEWI' 'K00NNENE' 'K00NNEAL'
#  'K00SOKOK' 'K00WARPH' 'K00WCALO' 'K00WCASA' 'K00WNEAL' 'K00WWYCH'
#  'S00MILCH' 'S00MMIDE' 'S00MMOBI' 'S00MNEOM' 'S00MNOFA' 'S00MSOSI'
#  'S00NCOHA' 'S00NMABA' 'S00NMABO' 'S00NNENE' 'S00NRHPR' 'S00SALBI'
#  'S00SMIJA' 'S00STEKN' 'S00STEDA' 'S00STEHO' 'S00SFLMI' 'S00SFLOR'
#  'S00SGEAT' 'S00SNOCH' 'S00SSOCH' 'S00SVIRI' 'S00WHAHO' 'S00WIDBO'
#  'S00WNEAL' 'W00NNENE' 'W00SARLI' 'W00SMIJA' 'W00STEHO' 'W00SFLOR'
#  'W00WHAHO' 'W00MININ' 'W00MIODE' 'W00MMIST' 'W00MOHCO' 'W00MWIMI'
#  'W00NMAPO' 'W00NMABA' 'W00NNEAL' 'W00NPEPH' 'W00NVEBU' 'W00NWECH'
#  'W00SLONE' 'W00SOKOK' 'W00SFLMI' 'W00WCASA' 'W00WCODE' 'W00WIDBO'
#  'W00WNELA' 'W00WORPO' 'W00WUTSA' 'W00WWASE']
# RETAILER
# ['Amazon' 'Foot Locker' "Kohl's" 'Sports Direct' 'Walmart' 'West Gear']
# REGION
# ['Midwest' 'Northeast' 'South' 'Southeast' 'West']
# STATE
# ['Ohio' 'Maine' 'Massachusetts' 'New Hampshire' 'Vermont' 'Alabama'
#  'Kentucky' 'North Carolina' 'Alaska' 'Illinois' 'Iowa' 'Kansas'
#  'Michigan' 'Minnesota' 'Missouri' 'Nebraska' 'North Dakota'
#  'South Dakota' 'Connecticut' 'Delaware' 'Maryland' 'New York'
#  'Pennsylvania' 'Rhode Island' 'West Virginia' 'Louisiana' 'Mississippi'
#  'Tennessee' 'Texas' 'Florida' 'Georgia' 'South Carolina' 'Virginia'
#  'Arizona' 'California' 'Hawaii' 'Idaho' 'Washington' 'Wyoming' 'Montana'
#  'New Jersey' 'Oklahoma' 'New Mexico' 'Arkansas' 'Indiana' 'Wisconsin'
#  'Colorado' 'Nevada' 'Oregon' 'Utah']
# CITY
# ['Columbus' 'Portland' 'Boston' 'Manchester' 'Burlington' 'Birmingham'
#  'Louisville' 'Charlotte' 'Anchorage' 'Chicago' 'Des Moines' 'Wichita'
#  'Detroit' 'Minneapolis' 'St. Louis' 'Omaha' 'Fargo' 'Sioux Falls'
#  'Hartford' 'Wilmington' 'Baltimore' 'New York' 'Philadelphia'
#  'Providence' 'Charleston' 'New Orleans' 'Jackson' 'Knoxville' 'Dallas'
#  'Miami' 'Atlanta' 'Richmond' 'Phoenix' 'Los Angeles' 'Honolulu' 'Boise'
#  'Seattle' 'Cheyenne' 'Billings' 'Newark' 'Albany' 'Oklahoma City'
#  'San Francisco' 'Albuquerque' 'Houston' 'Orlando' 'Little Rock'
#  'Indianapolis' 'Milwaukee' 'Denver' 'Las Vegas' 'Salt Lake City']

# %%
# erroneous values: retailer
retailer.describe()
# 110 entires but only 106 unique ids?
# Out:
#        RETAILER_ID     RETAILER     REGION    STATE        CITY
# count          110          110        110      110         110
# unique         106            6          5       50          52
# top       W00SFLOR  Foot Locker  Northeast  Florida  Charleston
# freq             2           33         28        6           4

# %%
# checking for duplicate_ids: retailer
retailer['RETAILER_ID'].value_counts()[lambda x: x > 1]
# Out:
# RETAILER_ID
# W00SFLOR    2
# S00NNENE    2
# W00SARLI    2
# W00STEHO    2
# Name: count, dtype: int64

# %% [markdown]
# ### Inspection: sales table

# %%
# Incorrect data formats or data types: sales
sales.info()
# order_id = object, invoice_date = datetime, product_id = object, units_sold = int, sales_method = str
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDER_ID          9648 non-null   int64
#  1   RETAILER_ID       9648 non-null   object
#  2   INVOICE_DATE      9648 non-null   object
#  3   MONTH             9648 non-null   int64
#  4   DAY               9648 non-null   int64
#  5   YEAR              9648 non-null   int64
#  6   PRODUCT_ID        9648 non-null   int64
#  7   PRICE_PER_UNIT    9646 non-null   float64
#  8   UNITS_SOLD        9648 non-null   object
#  9   OPERATING_MARGIN  9648 non-null   float64
#  10  SALES_METHOD      9648 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 829.3+ KB

# %%
# sum of duplicates: sales
sales.duplicated().sum()

print(f'Sum of duplicate values - sales: {sales.duplicated().sum()}')
# Out:
# Sum of duplicate values - sales: 0

# %%
# look for traditonal null or missing values: sales
sales.isnull().sum()
# 2 null values in price_per_unit
# Out:
# ORDER_ID            0
# RETAILER_ID         0
# INVOICE_DATE        0
# MONTH               0
# DAY                 0
# YEAR                0
# PRODUCT_ID          0
# PRICE_PER_UNIT      2
# UNITS_SOLD          0
# OPERATING_MARGIN    0
# SALES_METHOD        0
# dtype: int64

# %%
# Non-traditional null values; categorical data: sales
cat_var3 = list(sales.select_dtypes(include=['object']).columns)

for column in cat_var3:
  print(column)
  print(sales[column].unique())
# Out:
# RETAILER_ID
# ['A00MOHCO' 'A00NMAPO' 'A00NMABO' 'A00NNEMA' 'A00NVEBU' 'A00SALBI'
#  'A00SKELO' 'A00SNOCH' 'A00WALAN' 'F00SLONE' 'F00SGEAT' 'F00SVIRI'
#  'F00WALAN' 'F00WARPH' 'F00WHAHO' 'F00MNEOM' 'F00WIDBO' 'F00WWYCH'
#  'F00MILCH' 'F00MIODE' 'F00MKAWI' 'F00MMIDE' 'F00MMIMI' 'F00MMIST'
#  'F00MNOFA' 'F00MSOSI' 'F00NCOHA' 'F00NDEWI' 'F00NMABA' 'F00NNEMA'
#  'F00SFLMI' 'F00NNENE' 'F00NPEPH' 'F00SKELO' 'F00NRHPR' 'F00SSOCH'
#  'F00NWECH' 'F00SMIJA' 'F00STEKN' 'F00STEDA' 'F00WCALO' 'F00WWASE'
#  'K00WARPH' 'K00WNEAL' 'K00NDEWI' 'K00NNENE' 'K00NNEAL' 'K00WWYCH'
#  'K00MMIMI' 'K00MMOBI' 'K00WCALO' 'K00WCASA' 'K00MKAWI' 'K00SOKOK'
#  'S00MILCH' 'S00SFLOR' 'S00SGEAT' 'S00MMOBI' 'S00SVIRI' 'S00MNEOM'
#  'S00WHAHO' 'S00WNEAL' 'S00MMIDE' 'S00MNOFA' 'S00MSOSI' 'S00NCOHA'
#  'S00NMABA' 'S00NNENE' 'S00NMABO' 'S00NRHPR' 'S00SMIJA' 'S00SFLMI'
#  'S00SNOCH' 'S00SSOCH' 'S00SALBI' 'S00STEKN' 'S00STEDA' 'S00STEHO'
#  'S00WIDBO' 'W00SFLOR' 'W00WHAHO' 'W00NNENE' 'W00SMIJA' 'W00SARLI'
#  'W00STEHO' 'W00NMAPO' 'W00NPEPH' 'W00SLONE' 'W00WCASA' 'W00WCODE'
#  'W00WNELA' 'W00WORPO' 'W00WUTSA' 'W00WWASE' 'W00MININ' 'W00MIODE'
#  'W00MMIST' 'W00MOHCO' 'W00MWIMI' '999999999' 'W00NMABA' 'W00NNEAL'
#  'W00NVEBU' 'W00NWECH' 'W00SFLMI' 'W00SOKOK' 'W00WIDBO']
# INVOICE_DATE
# ['1/1/2020' '1/7/2020' '1/25/2020' '1/31/2020' '2/6/2020' '3/4/2020'
#  '3/10/2020' '3/16/2020' '4/19/2020' '4/27/2020' '5/3/2020' '7/19/2020'
#  '7/25/2020' '7/31/2020' '8/6/2020' '8/12/2020' '8/18/2020' '8/24/2020'
#  '8/30/2020' '9/5/2020' '9/11/2020' '10/20/2020' '10/26/2020' '11/1/2020'
#  '11/7/2020' '11/13/2020' '12/25/2020' '12/31/2020' '1/6/2021' '1/12/2021'
#  '1/18/2021' '1/24/2021' '1/30/2021' '2/5/2021' '2/11/2021' '2/17/2021'
#  '3/13/2021' '3/19/2021' '4/7/2021' '4/13/2021' '4/19/2021' '4/25/2021'
#  '5/1/2021' '5/7/2021' '5/13/2021' '5/19/2021' '5/25/2021' '5/31/2021'
#  '6/6/2021' '6/12/2021' '6/18/2021' '6/24/2021' '6/30/2021' '7/6/2021'
#  '7/12/2021' '7/18/2021' '7/24/2021' '7/30/2021' '8/5/2021' '8/11/2021'
#  '8/17/2021' '8/23/2021' '8/29/2021' '9/4/2021' '9/10/2021' '9/16/2021'
#  '9/22/2021' '9/28/2021' '10/4/2021' '10/10/2021' '10/16/2021'
#  '10/22/2021' '10/28/2021' '11/3/2021' '11/9/2021' '11/15/2021'
#  '11/21/2021' '11/27/2021' '12/3/2021' '12/9/2021' '12/15/2021'
#  '12/21/2021' '12/27/2021' '1/2/2020' '1/8/2020' '1/14/2020' '1/20/2020'
#  '1/26/2020' '2/1/2020' '2/7/2020' '2/13/2020' '2/19/2020' '2/25/2020'
#  '3/3/2020' '3/9/2020' '3/15/2020' '3/21/2020' '3/27/2020' '4/2/2020'
#  '4/8/2020' '4/14/2020' '4/20/2020' '4/26/2020' '5/2/2020' '5/8/2020'
#  '5/14/2020' '5/20/2020' '5/26/2020' '6/1/2020' '6/7/2020' '6/13/2020'
#  '6/19/2020' '6/25/2020' '7/1/2020' '7/7/2020' '7/13/2020' '4/24/2020'
#  '9/17/2020' '9/23/2020' '9/29/2020' '10/5/2020' '5/24/2020' '10/17/2020'
#  '10/23/2020' '10/29/2020' '11/4/2020' '11/10/2020' '11/16/2020'
#  '11/22/2020' '11/28/2020' '12/4/2020' '12/10/2020' '12/16/2020'
#  '12/22/2020' '12/28/2020' '1/3/2021' '1/9/2021' '1/15/2021' '1/21/2021'
#  '1/27/2021' '2/2/2021' '2/8/2021' '2/14/2021' '2/20/2021' '2/26/2021'
#  '3/4/2021' '3/10/2021' '3/16/2021' '3/22/2021' '3/28/2021' '4/3/2021'
#  '4/9/2021' '4/15/2021' '4/21/2021' '4/27/2021' '5/3/2021' '5/9/2021'
#  '5/15/2021' '5/21/2021' '5/27/2021' '6/2/2021' '6/8/2021' '6/14/2021'
#  '6/20/2021' '6/26/2021' '7/2/2021' '7/8/2021' '7/14/2021' '7/20/2021'
#  '7/26/2021' '8/1/2021' '8/7/2021' '8/13/2021' '8/19/2021' '8/25/2021'
#  '8/31/2021' '9/6/2021' '9/12/2021' '9/18/2021' '9/24/2021' '9/30/2021'
#  '10/6/2021' '10/12/2021' '10/18/2021' '10/24/2021' '10/30/2021'
#  '11/5/2021' '11/11/2021' '11/17/2021' '10/19/2021' '11/18/2021'
#  '12/17/2021' '1/10/2021' '2/22/2021' '3/20/2021' '5/20/2021' '6/22/2021'
#  '8/21/2021' '9/20/2021' '12/20/2021' '2/10/2021' '3/9/2021' '4/10/2021'
#  '5/11/2021' '6/10/2021' '7/9/2021' '8/10/2021' '9/11/2021' '11/10/2021'
#  '1/17/2021' '4/17/2021' '5/18/2021' '6/17/2021' '7/16/2021' '10/17/2021'
#  '12/16/2021' '3/8/2021' '5/8/2021' '8/9/2021' '9/8/2021' '12/8/2021'
#  '1/14/2021' '2/12/2021' '4/11/2021' '5/10/2021' '7/10/2021' '12/10/2021'
#  '2/24/2021' '3/23/2021' '4/24/2021' '7/23/2021' '8/24/2021' '9/25/2021'
#  '11/24/2021' '12/23/2021' '1/19/2021' '3/15/2021' '4/16/2021' '7/15/2021'
#  '8/16/2021' '9/15/2021' '11/16/2021' '2/18/2021' '3/17/2021' '4/18/2021'
#  '7/17/2021' '8/18/2021' '9/19/2021' '1/11/2021' '5/12/2021' '6/11/2021'
#  '10/11/2021' '1/5/2021' '2/4/2021' '3/6/2021' '4/5/2021' '5/5/2021'
#  '6/4/2021' '8/8/2021' '9/5/2021' '12/4/2021' '1/23/2021' '2/23/2021'
#  '4/23/2021' '5/24/2021' '6/23/2021' '7/22/2021' '10/23/2021' '11/23/2021'
#  '12/22/2021' '1/26/2021' '3/25/2021' '4/26/2021' '7/25/2021' '8/26/2021'
#  '9/27/2021' '10/26/2021' '11/26/2021' '12/25/2021' '1/13/2021'
#  '2/13/2021' '3/12/2021' '5/14/2021' '6/13/2021' '9/14/2021' '10/13/2021'
#  '11/13/2021' '12/12/2021' '2/7/2021' '3/5/2021' '4/6/2021' '6/7/2021'
#  '7/5/2021' '8/6/2021' '10/7/2021' '11/6/2021' '12/5/2021' '3/2/2021'
#  '5/2/2021' '8/3/2021' '9/2/2021' '12/2/2021' '9/9/2021' '1/22/2021'
#  '3/21/2021' '4/22/2021' '5/23/2021' '7/21/2021' '8/22/2021' '9/23/2021'
#  '11/22/2021' '1/20/2021' '5/16/2021' '2/21/2021' '4/20/2021' '6/21/2021'
#  '7/19/2021' '8/20/2021' '10/21/2021' '11/20/2021' '12/19/2021'
#  '1/16/2021' '10/14/2021' '3/11/2021' '4/12/2021' '7/11/2021' '8/12/2021'
#  '9/13/2021' '11/12/2021' '12/11/2021' '2/9/2021' '6/9/2021' '10/9/2021'
#  '2/6/2021' '9/7/2021' '2/3/2021' '5/4/2021' '6/3/2021' '10/3/2021'
#  '2/15/2021' '4/14/2021' '6/15/2021' '7/13/2021' '8/14/2021' '10/15/2021'
#  '11/14/2021' '12/13/2021' '5/6/2021' '10/8/2021' '11/7/2021' '12/6/2021'
#  '1/7/2021' '3/3/2021' '4/4/2021' '6/5/2021' '7/3/2021' '8/4/2021'
#  '9/3/2021' '10/5/2021' '11/4/2021' '2/19/2021' '5/17/2021' '6/19/2021'
#  '9/17/2021' '3/5/2020' '3/11/2020' '3/17/2020' '4/28/2020' '5/4/2020'
#  '7/20/2020' '7/26/2020' '8/1/2020' '8/7/2020' '8/13/2020' '8/19/2020'
#  '8/25/2020' '8/31/2020' '9/6/2020' '9/12/2020' '10/21/2020' '10/27/2020'
#  '11/2/2020' '11/8/2020' '11/14/2020' '12/26/2020' '1/1/2021' '1/25/2021'
#  '1/31/2021' '3/14/2021' '4/8/2021' '5/26/2021' '6/1/2021' '6/25/2021'
#  '7/1/2021' '7/7/2021' '7/31/2021' '8/30/2021' '9/29/2021' '10/29/2021'
#  '11/28/2021' '12/28/2021' '1/3/2020' '1/9/2020' '1/15/2020' '1/21/2020'
#  '1/27/2020' '2/2/2020' '2/8/2020' '2/14/2020' '2/20/2020' '2/26/2020'
#  '3/22/2020' '3/28/2020' '4/3/2020' '4/9/2020' '4/15/2020' '4/21/2020'
#  '5/9/2020' '5/15/2020' '5/21/2020' '5/27/2020' '6/2/2020' '6/8/2020'
#  '6/14/2020' '6/20/2020' '6/26/2020' '7/2/2020' '7/8/2020' '7/14/2020'
#  '9/18/2020' '9/24/2020' '9/30/2020' '10/6/2020' '10/18/2020' '10/24/2020'
#  '10/30/2020' '11/5/2020' '11/11/2020' '11/17/2020' '11/23/2020'
#  '11/29/2020' '12/5/2020' '12/11/2020' '12/17/2020' '12/23/2020'
#  '12/29/2020' '1/4/2021' '1/28/2021' '2/27/2021' '3/29/2021' '4/28/2021'
#  '5/22/2021' '5/28/2021' '6/27/2021' '7/27/2021' '8/2/2021' '9/1/2021'
#  '10/1/2021' '10/25/2021' '10/31/2021' '1/5/2020' '1/23/2020' '1/29/2020'
#  '2/4/2020' '2/10/2020' '3/8/2020' '3/14/2020' '4/17/2020' '4/23/2020'
#  '4/25/2020' '5/1/2020' '5/7/2020' '7/23/2020' '7/29/2020' '8/4/2020'
#  '8/10/2020' '8/16/2020' '8/22/2020' '8/28/2020' '9/3/2020' '9/9/2020'
#  '9/15/2020' '4/29/2021' '5/29/2021' '6/16/2021' '6/28/2021' '7/4/2021'
#  '7/28/2021' '8/15/2021' '8/27/2021' '9/26/2021' '10/2/2021' '10/20/2021'
#  '11/1/2021' '11/19/2021' '11/25/2021' '12/1/2021' '12/7/2021'
#  '12/31/2021' '1/6/2020' '1/12/2020' '1/18/2020' '1/24/2020' '1/30/2020'
#  '2/5/2020' '2/11/2020' '2/17/2020' '2/23/2020' '3/1/2020' '3/7/2020'
#  '3/13/2020' '3/19/2020' '3/25/2020' '3/31/2020' '4/6/2020' '4/12/2020'
#  '4/18/2020' '4/30/2020' '5/6/2020' '5/12/2020' '5/18/2020' '5/30/2020'
#  '6/5/2020' '6/11/2020' '6/17/2020' '6/23/2020' '6/29/2020' '7/5/2020'
#  '7/11/2020' '7/17/2020' '9/21/2020' '9/27/2020' '10/3/2020' '10/9/2020'
#  '11/20/2020' '11/26/2020' '12/2/2020' '12/8/2020' '12/14/2020'
#  '12/20/2020' '3/26/2021' '4/1/2021' '3/6/2020' '3/12/2020' '3/18/2020'
#  '4/29/2020' '5/5/2020' '7/21/2020' '7/27/2020' '8/2/2020' '8/8/2020'
#  '8/14/2020' '8/20/2020' '8/26/2020' '9/1/2020' '9/7/2020' '9/13/2020'
#  '10/22/2020' '10/28/2020' '11/3/2020' '11/9/2020' '11/15/2020'
#  '12/27/2020' '1/2/2021' '1/8/2021' '2/1/2021' '11/29/2021' '12/29/2021'
#  '1/4/2020' '1/10/2020' '1/16/2020' '1/22/2020' '1/28/2020' '2/3/2020'
#  '2/9/2020' '2/15/2020' '2/21/2020' '2/27/2020' '3/23/2020' '3/29/2020'
#  '4/4/2020' '4/10/2020' '4/16/2020' '4/22/2020' '5/10/2020' '5/16/2020'
#  '5/22/2020' '5/28/2020' '6/3/2020' '6/9/2020' '6/15/2020' '6/21/2020'
#  '6/27/2020' '7/3/2020' '7/9/2020' '7/15/2020' '9/19/2020' '9/25/2020'
#  '10/1/2020' '10/7/2020' '10/19/2020' '10/25/2020' '10/31/2020'
#  '11/6/2020' '11/12/2020' '11/18/2020' '11/24/2020' '11/30/2020'
#  '12/6/2020' '12/12/2020' '12/18/2020' '12/24/2020' '12/30/2020'
#  '1/29/2021' '2/16/2021' '2/28/2021' '3/18/2021' '3/24/2021' '3/30/2021'
#  '7/22/2020' '7/28/2020' '8/3/2020' '8/9/2020' '8/15/2020' '8/21/2020'
#  '8/27/2020' '9/2/2020' '9/8/2020' '9/14/2020' '11/30/2021' '12/18/2021'
#  '12/24/2021' '12/30/2021' '1/11/2020' '1/17/2020' '2/16/2020' '2/22/2020'
#  '2/28/2020' '3/24/2020' '3/30/2020' '4/5/2020' '4/11/2020' '5/11/2020'
#  '5/17/2020' '5/23/2020' '5/29/2020' '6/4/2020' '6/10/2020' '6/16/2020'
#  '6/22/2020' '6/28/2020' '7/4/2020' '7/10/2020' '7/16/2020' '9/20/2020'
#  '9/26/2020' '10/2/2020' '10/8/2020' '11/19/2020' '11/25/2020' '12/1/2020'
#  '12/7/2020' '12/13/2020' '12/19/2020' '3/1/2021' '3/7/2021' '3/31/2021'
#  '4/30/2021' '5/30/2021' '6/29/2021' '7/29/2021' '8/28/2021' '9/21/2021'
#  '10/27/2021' '11/2/2021' '11/8/2021' '7/18/2020' '7/24/2020' '7/30/2020'
#  '8/5/2020' '8/11/2020' '8/17/2020' '8/23/2020' '8/29/2020' '9/4/2020'
#  '9/10/2020' '9/16/2020' '12/14/2021' '12/26/2021' '1/13/2020' '1/19/2020'
#  '2/12/2020' '2/18/2020' '2/24/2020' '3/2/2020' '3/20/2020' '3/26/2020'
#  '4/1/2020' '4/7/2020' '4/13/2020' '5/13/2020' '5/19/2020' '5/25/2020'
#  '5/31/2020' '6/6/2020' '6/12/2020' '6/18/2020' '6/24/2020' '6/30/2020'
#  '7/6/2020' '7/12/2020' '9/22/2020' '9/28/2020' '10/4/2020' '10/10/2020'
#  '11/21/2020' '11/27/2020' '12/3/2020' '12/9/2020' '12/15/2020'
#  '12/21/2020' '2/25/2021' '3/27/2021' '4/2/2021']
# UNITS_SOLD
# ['1200' '1250' '1220' '1275' '1150' '900' '850' '875' '925' '950' '800'
#  '775' '825' '975' '1025' '700' '750' '475' '525' '495' '450' '500' '575'
#  '550' '425' '400' '725' '675' '625' '445' '470' '375' '600' '1050' '1100'
#  '1070' '1075' '1125' '1000' '350' '650' '420' '325' '300' '545' '570'
#  '870' '820' '770' '795' '620' '670' '1020' '1045' '920' '945' '520' '720'
#  '745' '645' '595' '336' '313' '354' '317' '319' '360' '299' '312' '234'
#  '213' '254' '268' '238' '255' '240' '209' '223' '230' '228' '252' '273'
#  '277' '241' '236' '263' '293' '203' '225' '216' '208' '270' '224' '231'
#  '124' '158' '144' '122' '134' '135' '161' '149' '115' '112' '150' '189'
#  '176' '182' '195' '181' '156' '111' '119' '120' '136' '145' '143' '104'
#  '113' '160' '218' '210' '174' '138' '155' '196' '123' '131' '165' '202'
#  '162' '137' '117' '167' '239' '217' '188' '256' '290' '304' '284' '244'
#  '323' '116' '106' '98' '91' '173' '169' '180' '215' '233' '200' '105'
#  '118' '94' '84' '163' '206' '175' '140' '127' '147' '153' '109' '130'
#  '261' '100' '248' '247' '250' '245' '246' '125' '102' '207' '232' '186'
#  '168' '128' '142' '133' '154' '***' '265' '283' '282' '311' '326' '287'
#  '278' '276' '294' '308' '194' '126' '187' '221' '152' '139' '129' '146'
#  '141' '151' '164' '179' '88' '108' '95' '384' '388' '390' '372' '366'
#  '434' '408' '403' '306' '315' '295' '305' '264' '272' '333' '289' '271'
#  '341' '338' '302' '322' '297' '285' '281' '166' '170' '171' '201' '184'
#  '280' '288' '298' '190' '219' '204' '349' '376' '178' '192' '191' '132'
#  '185' '177' '157' '193' '275' '75' '260' '259' '267' '243' '77' '51' '60'
#  '44' '54' '63' '81' '65' '68' '35' '38' '45' '53' '70' '90' '80' '69'
#  '28' '49' '87' '73' '58' '52' '101' '56' '26' '23' '33' '41' '46' '59'
#  '74' '61' '72' '85' '83' '78' '47' '50' '42' '39' '31' '36' '320' '296'
#  '340' '318' '359' '310' '332' '99' '107' '198' '79' '93' '96' '64' '40'
#  '114' '25' '20' '22' '27' '19' '14' '34' '13' '6' '21' '7' '29' '30' '15'
#  '279' '24' '48' '62' '66' '43' '345' '695' '220' '395' '257' '258' '55'
#  '57' '86' '314' '374' '103' '0' '8' '324' '17' '16' '32' '286' '330'
#  '347' '352' '355']
# SALES_METHOD
# ['In-store' 'Outlet' 'Ootlet' 'Online']

# %%
# erroneous values: sales
sales.describe()
# max for price_per_unit is 99,999?
# Out:
#           ORDER_ID        MONTH          DAY         YEAR   PRODUCT_ID  \
# count  9648.000000  9648.000000  9648.000000  9648.000000  9648.000000
# mean   4824.500000     6.458126    14.696310  2020.865050    79.975124
# std    2785.282032     3.454799     7.348019     0.341688    50.668992
# min       1.000000     1.000000     1.000000  2020.000000    20.000000
# 25%    2412.750000     3.000000     9.000000  2021.000000    30.000000
# 50%    4824.500000     6.000000    15.000000  2021.000000    40.000000
# 75%    7236.250000     9.000000    21.000000  2021.000000   130.000000
# max    9648.000000    12.000000    31.000000  2021.000000   140.000000
#
#        PRICE_PER_UNIT  OPERATING_MARGIN
# count     9646.000000       9648.000000
# mean        55.575264          0.422991
# std       1017.819943          0.097197
# min          7.000000          0.100000
# 25%         35.000000          0.350000
# 50%         45.000000          0.410000
# 75%         55.000000          0.490000
# max      99999.000000          0.800000

# %%
# checking for any out of place values in the price_per_unit column

# Largest values first
sales['PRICE_PER_UNIT'].sort_values(ascending=False).head(20)
# found a price_per_unit value of 99,999 which is inconsistent with other rows. Going to have to remove it.
# Out:
# 423     99999.0
# 8368      110.0
# 8272      110.0
# 8273      110.0
# 8369      110.0
# 8308      105.0
# 8309      105.0
# 8356      105.0
# 8357      105.0
# 9017      103.0
# 8920      103.0
# 8921      101.0
# 8260      100.0
# 8154      100.0
# 8153      100.0
# 8261      100.0
# 9016      100.0
# 8801       98.0
# 8908       97.0
# 9005       97.0
# Name: PRICE_PER_UNIT, dtype: float64

# %%
# checking for duplicate_ids: sales
sales['ORDER_ID'].value_counts()[lambda x: x > 1]
# 0
# Out:
# Series([], Name: count, dtype: int64)

# %%
# looking for outliers not relevant

# %% [markdown]
# ## Data Cleaning

# %%
# products table
# convert product_id to an object type; convert product_name to a str
products['PRODUCT_ID'] = products['PRODUCT_ID'].astype(object)
products.dtypes
# Out:
# PRODUCT_ID      object
# PRODUCT_NAME    object
# dtype: object

# %%
# retailer table
# remove duplicates rows based the RETAILER_ID column
retailer = retailer.drop_duplicates(subset='RETAILER_ID')
retailer['RETAILER_ID'].value_counts()[lambda x: x > 1]
# Out:
# Series([], Name: count, dtype: int64)

# %%
# sales tables
# drop rows based on null values in the price_per_unit column
sales = sales.dropna(subset=['PRICE_PER_UNIT'])
sales.isnull().sum()
# Out:
# ORDER_ID            0
# RETAILER_ID         0
# INVOICE_DATE        0
# MONTH               0
# DAY                 0
# YEAR                0
# PRODUCT_ID          0
# PRICE_PER_UNIT      0
# UNITS_SOLD          0
# OPERATING_MARGIN    0
# SALES_METHOD        0
# dtype: int64

# %%
# sales table continued
# drop the row with 99999 in the price_per_unit column
sales = sales[sales['PRICE_PER_UNIT'] != 99999]
sales.describe()
# Out:
#           ORDER_ID        MONTH          DAY         YEAR   PRODUCT_ID  \
# count  9645.000000  9645.000000  9645.000000  9645.000000  9645.000000
# mean   4825.614515     6.458787    14.697460  2020.865215    79.993779
# std    2784.951237     3.455123     7.347222     0.341511    50.665828
# min       1.000000     1.000000     1.000000  2020.000000    20.000000
# 25%    2414.000000     3.000000     9.000000  2021.000000    30.000000
# 50%    4826.000000     6.000000    15.000000  2021.000000    40.000000
# 75%    7237.000000     9.000000    21.000000  2021.000000   130.000000
# max    9648.000000    12.000000    31.000000  2021.000000   140.000000
#
#        PRICE_PER_UNIT  OPERATING_MARGIN
# count     9645.000000       9645.000000
# mean        45.213064          0.422993
# std         14.706062          0.097206
# min          7.000000          0.100000
# 25%         35.000000          0.350000
# 50%         45.000000          0.410000
# 75%         55.000000          0.490000
# max        110.000000          0.800000

# %% [markdown]
# ## Data Analysis

# %%
# Question 1: What product category (product) had the highest sales (in dollars) in 2021? How much did it sell?

# %%
# join the products and sales on the PRODUCT_ID key
products_sales = pd.merge(products, sales, on='PRODUCT_ID', how='right')
products_sales.head()
# Out:
#   PRODUCT_ID           PRODUCT_NAME  ORDER_ID RETAILER_ID INVOICE_DATE  MONTH  \
# 0         20  Men's Street Footwear         1    A00MOHCO     1/1/2020      1
# 1         20  Men's Street Footwear         7    A00MOHCO     1/7/2020      1
# 2         20  Men's Street Footwear        13    A00MOHCO    1/25/2020      1
# 3         20  Men's Street Footwear        19    A00MOHCO    1/31/2020      1
# 4         20  Men's Street Footwear        25    A00MOHCO     2/6/2020      2
#
#    DAY  YEAR  PRICE_PER_UNIT UNITS_SOLD  OPERATING_MARGIN SALES_METHOD
# 0    1  2020            50.0       1200               0.5     In-store
# 1    7  2020            50.0       1250               0.5     In-store
# 2   25  2020            50.0       1220               0.5       Outlet
# 3   31  2020            50.0       1200               0.5       Outlet
# 4    6  2020            60.0       1220               0.5       Outlet

# %%
# filter product_sales to show only sales that took place in 2021
products_sales_2021 = products_sales[products_sales['YEAR'] == 2021]
display(products_sales_2021.head())
# Out:
#    PRODUCT_ID           PRODUCT_NAME  ORDER_ID RETAILER_ID INVOICE_DATE  \
# 28         20  Men's Street Footwear       171    A00NMAPO     1/6/2021
# 29         20  Men's Street Footwear       177    A00NMAPO    1/12/2021
# 30         20  Men's Street Footwear       183    A00NMAPO    1/18/2021
# 31         20  Men's Street Footwear       189    A00NMAPO    1/24/2021
# 32         20  Men's Street Footwear       195    A00NMAPO    1/30/2021
#
#     MONTH  DAY  YEAR  PRICE_PER_UNIT UNITS_SOLD  OPERATING_MARGIN SALES_METHOD
# 28      1    6  2021            60.0        975              0.40       Outlet
# 29      1   12  2021            60.0       1025              0.35       Outlet
# 30      1   18  2021            65.0        975              0.35       Outlet
# 31      1   24  2021            55.0        925              0.30       Outlet
# 32      1   30  2021            55.0        875              0.30       Outlet

# %%
# create a pivot table for the price_per_unit by the product_name using the product_sales_2021 dataframe
products_sales_pivot = pd.pivot_table(products_sales_2021, index='PRODUCT_NAME', values='PRICE_PER_UNIT', aggfunc='sum')
products_sales_pivot.sort_values(by='PRICE_PER_UNIT', ascending=False)
# answer to Question 1: Women's Apparel; $70,472
# Out:
#                            PRICE_PER_UNIT
# PRODUCT_NAME
# Women's Apparel                   70472.0
# Men's Apparel                     68992.0
# Men's Street Footwear             60712.0
# Men's Athletic Footwear           59692.0
# Women's Athletic Footwear         55824.0
# Women's Street Footwear           54588.0

# %%
# Question 2: What state had the highest sales (in dollars) of women's products in 2021? How much was it?

# %%
# join the sales and retailer table on the RETAILER_ID column
sales_retailer = pd.merge(sales, retailer, on='RETAILER_ID', how='left')

# %%
# join the sales_retailer table with product table on the PRODUCT_ID
sales_retailer_products = pd.merge(sales_retailer, products, on='PRODUCT_ID', how='left')
sales_retailer_products.head()
# Out:
#    ORDER_ID RETAILER_ID INVOICE_DATE  MONTH  DAY  YEAR PRODUCT_ID  \
# 0         1    A00MOHCO     1/1/2020      1    1  2020         20
# 1         7    A00MOHCO     1/7/2020      1    7  2020         20
# 2        13    A00MOHCO    1/25/2020      1   25  2020         20
# 3        19    A00MOHCO    1/31/2020      1   31  2020         20
# 4        25    A00MOHCO     2/6/2020      2    6  2020         20
#
#    PRICE_PER_UNIT UNITS_SOLD  OPERATING_MARGIN SALES_METHOD RETAILER   REGION  \
# 0            50.0       1200               0.5     In-store   Amazon  Midwest
# 1            50.0       1250               0.5     In-store   Amazon  Midwest
# 2            50.0       1220               0.5       Outlet   Amazon  Midwest
# 3            50.0       1200               0.5       Outlet   Amazon  Midwest
# 4            60.0       1220               0.5       Outlet   Amazon  Midwest
#
#   STATE      CITY           PRODUCT_NAME
# 0  Ohio  Columbus  Men's Street Footwear
# 1  Ohio  Columbus  Men's Street Footwear
# 2  Ohio  Columbus  Men's Street Footwear
# 3  Ohio  Columbus  Men's Street Footwear
# 4  Ohio  Columbus  Men's Street Footwear

# %%
# filter sales_retailer_products to show only 2021 sales
sales_retailer_products_2021 = sales_retailer_products[sales_retailer_products['YEAR'] == 2021]
display(sales_retailer_products_2021.head())
# Out:
#     ORDER_ID RETAILER_ID INVOICE_DATE  MONTH  DAY  YEAR PRODUCT_ID  \
# 28       171    A00NMAPO     1/6/2021      1    6  2021         20
# 29       177    A00NMAPO    1/12/2021      1   12  2021         20
# 30       183    A00NMAPO    1/18/2021      1   18  2021         20
# 31       189    A00NMAPO    1/24/2021      1   24  2021         20
# 32       195    A00NMAPO    1/30/2021      1   30  2021         20
#
#     PRICE_PER_UNIT UNITS_SOLD  OPERATING_MARGIN SALES_METHOD RETAILER  \
# 28            60.0        975              0.40       Outlet   Amazon
# 29            60.0       1025              0.35       Outlet   Amazon
# 30            65.0        975              0.35       Outlet   Amazon
# 31            55.0        925              0.30       Outlet   Amazon
# 32            55.0        875              0.30       Outlet   Amazon
#
#        REGION  STATE      CITY           PRODUCT_NAME
# 28  Northeast  Maine  Portland  Men's Street Footwear
# 29  Northeast  Maine  Portland  Men's Street Footwear
# 30  Northeast  Maine  Portland  Men's Street Footwear
# 31  Northeast  Maine  Portland  Men's Street Footwear
# 32  Northeast  Maine  Portland  Men's Street Footwear

# %%
# filter sales_retailer_products_2021 to show only sales that have Women's Apparel, Women's Athletic Footwear, and Women's Street Footwear in the PRODUCT_NAME column
sales_retailer_products_2021_women = sales_retailer_products_2021[sales_retailer_products_2021['PRODUCT_NAME'].isin(['Women\'s Apparel', 'Women\'s Athletic Footwear', 'Women\'s Street Footwear'])]
display(sales_retailer_products_2021_women.head())
# Out:
#       ORDER_ID RETAILER_ID INVOICE_DATE  MONTH  DAY  YEAR PRODUCT_ID  \
# 4850       167    A00NMAPO     1/2/2021      1    2  2021        120
# 4851       173    A00NMAPO     1/8/2021      1    8  2021        120
# 4852       179    A00NMAPO    1/14/2021      1   14  2021        120
# 4853       185    A00NMAPO    1/20/2021      1   20  2021        120
# 4854       191    A00NMAPO    1/26/2021      1   26  2021        120
#
#       PRICE_PER_UNIT UNITS_SOLD  OPERATING_MARGIN SALES_METHOD RETAILER  \
# 4850            65.0        750              0.40       Outlet   Amazon
# 4851            65.0        825              0.40       Outlet   Amazon
# 4852            65.0        825              0.35       Outlet   Amazon
# 4853            65.0        800              0.35       Outlet   Amazon
# 4854            55.0        775              0.30       Outlet   Amazon
#
#          REGION  STATE      CITY             PRODUCT_NAME
# 4850  Northeast  Maine  Portland  Women's Street Footwear
# 4851  Northeast  Maine  Portland  Women's Street Footwear
# 4852  Northeast  Maine  Portland  Women's Street Footwear
# 4853  Northeast  Maine  Portland  Women's Street Footwear
# 4854  Northeast  Maine  Portland  Women's Street Footwear

# %%
# create a pivot table for price_per_unit based on state using sales_retailer_products_2021_women dataframe
sales_retailer_products_2021_women_pivot = pd.pivot_table(sales_retailer_products_2021_women, index='STATE', values='PRICE_PER_UNIT', aggfunc='sum')
sales_retailer_products_2021_women_pivot.sort_values(by='PRICE_PER_UNIT', ascending=False)
# answer to Question 2: California; $8,540
# Out:
#                 PRICE_PER_UNIT
# STATE
# California              8540.0
# Texas                   8304.0
# Connecticut             6239.0
# New York                6058.0
# Arizona                 5905.0
# Florida                 5674.0
# New Mexico              5276.0
# New Hampshire           5130.0
# Massachusetts           5053.0
# Alabama                 4969.0
# Tennessee               4944.0
# Virginia                4669.0
# Louisiana               4621.0
# Idaho                   4572.0
# Rhode Island            4186.0
# Pennsylvania            4152.0
# Missouri                4062.0
# South Dakota            4055.0
# Hawaii                  3951.0
# Mississippi             3789.0
# Arkansas                3596.0
# Nebraska                3567.0
# Delaware                3535.0
# Illinois                3499.0
# South Carolina          3449.0
# North Dakota            3432.0
# Montana                 3339.0
# Maine                   3185.0
# Indiana                 3168.0
# Iowa                    3121.0
# Maryland                3084.0
# Utah                    3040.0
# Wisconsin               2969.0
# New Jersey              2922.0
# Oklahoma                2779.0
# Oregon                  2603.0
# West Virginia           2528.0
# Nevada                  2450.0
# Washington              2393.0
# Michigan                2389.0
# North Carolina          2320.0
# Georgia                 2310.0
# Minnesota               2293.0
# Alaska                  2240.0
# Colorado                2067.0
# Wyoming                 1656.0
# Kansas                  1070.0
# Vermont                 1005.0
# Kentucky                 605.0
# Ohio                     121.0

# %%
# Question 3: What state had the highest sales (in dollars) of men's products in 2021? How much was it?

# %%
# filter sales_retailer_products_2021 to show only sales that have Men's Apparel, Men's Athletic Footwear, and Men's Street Footwear in the PRODUCT_NAME column
sales_retailer_products_2021_men = sales_retailer_products_2021[sales_retailer_products_2021['PRODUCT_NAME'].isin(['Men\'s Apparel', 'Men\'s Athletic Footwear', 'Men\'s Street Footwear'])]
display(sales_retailer_products_2021_men.head())
# Out:
#     ORDER_ID RETAILER_ID INVOICE_DATE  MONTH  DAY  YEAR PRODUCT_ID  \
# 28       171    A00NMAPO     1/6/2021      1    6  2021         20
# 29       177    A00NMAPO    1/12/2021      1   12  2021         20
# 30       183    A00NMAPO    1/18/2021      1   18  2021         20
# 31       189    A00NMAPO    1/24/2021      1   24  2021         20
# 32       195    A00NMAPO    1/30/2021      1   30  2021         20
#
#     PRICE_PER_UNIT UNITS_SOLD  OPERATING_MARGIN SALES_METHOD RETAILER  \
# 28            60.0        975              0.40       Outlet   Amazon
# 29            60.0       1025              0.35       Outlet   Amazon
# 30            65.0        975              0.35       Outlet   Amazon
# 31            55.0        925              0.30       Outlet   Amazon
# 32            55.0        875              0.30       Outlet   Amazon
#
#        REGION  STATE      CITY           PRODUCT_NAME
# 28  Northeast  Maine  Portland  Men's Street Footwear
# 29  Northeast  Maine  Portland  Men's Street Footwear
# 30  Northeast  Maine  Portland  Men's Street Footwear
# 31  Northeast  Maine  Portland  Men's Street Footwear
# 32  Northeast  Maine  Portland  Men's Street Footwear

# %%
# create a pivot table for price_per_unit based on state using sales_retailer_products_2021_men dataframe
sales_retailer_products_2021_men_pivot = sales_retailer_products_2021_men.pivot_table(index='STATE', values='PRICE_PER_UNIT', aggfunc='sum')
sales_retailer_products_2021_men_pivot.sort_values(by='PRICE_PER_UNIT', ascending=False)
# answer to Question 3: Texas; $9,194
# Out:
#                 PRICE_PER_UNIT
# STATE
# Texas                   9194.0
# California              8899.0
# Connecticut             6409.0
# New York                6344.0
# Florida                 6306.0
# Arizona                 6154.0
# New Mexico              5527.0
# New Hampshire           5365.0
# Massachusetts           5334.0
# Tennessee               5175.0
# Louisiana               4964.0
# Idaho                   4958.0
# Rhode Island            4768.0
# Alabama                 4642.0
# Pennsylvania            4481.0
# Virginia                4480.0
# Mississippi             4397.0
# Missouri                4065.0
# Arkansas                4037.0
# South Dakota            3934.0
# Hawaii                  3848.0
# Illinois                3766.0
# South Carolina          3685.0
# Delaware                3635.0
# Montana                 3471.0
# Nebraska                3428.0
# North Dakota            3397.0
# Utah                    3395.0
# Iowa                    3262.0
# Maryland                3198.0
# Indiana                 3163.0
# Maine                   3106.0
# New Jersey              2995.0
# Oklahoma                2966.0
# Wisconsin               2915.0
# Oregon                  2681.0
# Michigan                2664.0
# West Virginia           2576.0
# Georgia                 2503.0
# Minnesota               2502.0
# North Carolina          2477.0
# Nevada                  2366.0
# Washington              2322.0
# Alaska                  2270.0
# Colorado                2257.0
# Wyoming                 1845.0
# Kansas                  1180.0
# Vermont                 1006.0
# Kentucky                 820.0
# Ohio                     204.0

# %%
# What retailer purchased the most units in 2021? In 2020?
# Out:
# array([2020, 2021])

# %%
# filter the sales_retailer dataframe to show only 2021 sales orders
sales_retailer_2021 = sales_retailer[sales_retailer['YEAR'] == 2021]
display(sales_retailer_2021.head())
# Out:
#     ORDER_ID RETAILER_ID INVOICE_DATE  MONTH  DAY  YEAR  PRODUCT_ID  \
# 28       171    A00NMAPO     1/6/2021      1    6  2021          20
# 29       177    A00NMAPO    1/12/2021      1   12  2021          20
# 30       183    A00NMAPO    1/18/2021      1   18  2021          20
# 31       189    A00NMAPO    1/24/2021      1   24  2021          20
# 32       195    A00NMAPO    1/30/2021      1   30  2021          20
#
#     PRICE_PER_UNIT UNITS_SOLD  OPERATING_MARGIN SALES_METHOD RETAILER  \
# 28            60.0        975              0.40       Outlet   Amazon
# 29            60.0       1025              0.35       Outlet   Amazon
# 30            65.0        975              0.35       Outlet   Amazon
# 31            55.0        925              0.30       Outlet   Amazon
# 32            55.0        875              0.30       Outlet   Amazon
#
#        REGION  STATE      CITY
# 28  Northeast  Maine  Portland
# 29  Northeast  Maine  Portland
# 30  Northeast  Maine  Portland
# 31  Northeast  Maine  Portland
# 32  Northeast  Maine  Portland

# %%
# create a pivot table for UNITS_SOLD by retailer using the sales_retailer_2021 dataframe
sales_retailer_2021_pivot = pd.pivot_table(sales_retailer_2021, index='RETAILER', values='UNITS_SOLD', aggfunc='sum')
sales_retailer_2021_pivot.sort_values(by='UNITS_SOLD', ascending=False)
# answer to Question 4, part 1: Amazon (2021)
# Out:
#                                                       UNITS_SOLD
# RETAILER
# Amazon         9751025975925875875975700750800800800900950900...
# Foot Locker    6757257758257756755756758004254754203754204005...
# Kohl's         4254754454254705505755504253753505004505004704...
# Walmart        1821891501371331691491621531501431441821891651...
# Sports Direct  1581731611501692032031801601671962101691891691...
# West Gear      1581311601891821631421281351681381471441331301...

# %%
# filter the sales_retailer dataframe to show only 2020 sales orders
sales_retailer_2020 = sales_retailer[sales_retailer['YEAR'] == 2020]
display(sales_retailer_2020.head())
# Out:
#    ORDER_ID RETAILER_ID INVOICE_DATE  MONTH  DAY  YEAR  PRODUCT_ID  \
# 0         1    A00MOHCO     1/1/2020      1    1  2020          20
# 1         7    A00MOHCO     1/7/2020      1    7  2020          20
# 2        13    A00MOHCO    1/25/2020      1   25  2020          20
# 3        19    A00MOHCO    1/31/2020      1   31  2020          20
# 4        25    A00MOHCO     2/6/2020      2    6  2020          20
#
#    PRICE_PER_UNIT UNITS_SOLD  OPERATING_MARGIN SALES_METHOD RETAILER   REGION  \
# 0            50.0       1200               0.5     In-store   Amazon  Midwest
# 1            50.0       1250               0.5     In-store   Amazon  Midwest
# 2            50.0       1220               0.5       Outlet   Amazon  Midwest
# 3            50.0       1200               0.5       Outlet   Amazon  Midwest
# 4            60.0       1220               0.5       Outlet   Amazon  Midwest
#
#   STATE      CITY
# 0  Ohio  Columbus
# 1  Ohio  Columbus
# 2  Ohio  Columbus
# 3  Ohio  Columbus
# 4  Ohio  Columbus

# %%
# create a pivot table for UNITS_SOLD by retailer using the sales_retailer_2020 dataframe
sales_retailer_2020_pivot = pd.pivot_table(sales_retailer_2020, index='RETAILER', values='UNITS_SOLD', aggfunc='sum')
sales_retailer_2020_pivot.sort_values(by='UNITS_SOLD', ascending=False)
# answer to Question 4, part 2: West Gear (2020)
# Out:
#                                                       UNITS_SOLD
# RETAILER
# West Gear      3843883903723664004343754084034202702553063063...
# Kohl's         3363133543003173133193253602993122342132542342...
# Sports Direct  2682563002902993042842702443231311351161201161...
# Amazon         1200125012201200122012501275125012001150120090...

# %%
# create a pivot table for price_per_unit by sales_method using sales_retailer_2021 dataframe (additional insight)
sales_retailer_2021_pivot = pd.pivot_table(sales_retailer_2021, index='SALES_METHOD', values='PRICE_PER_UNIT', aggfunc='sum')
sales_retailer_2021_pivot.sort_values(by='PRICE_PER_UNIT', ascending=False)
# Online and Outlet had the highest sales in 2021
# Out:
#               PRICE_PER_UNIT
# SALES_METHOD
# Online              196939.0
# Outlet              104971.0
# In-store             67895.0
# Ootlet                 475.0
